# %% [markdown]
# # **cara download data csv 1 (kaggle)**

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("lainguyn123/student-performance-factors")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/lainguyn123/student-performance-factors/versions/6

# %%
import os

dataset_path = '/root/.cache/kagglehub/datasets/lainguyn123/student-performance-factors/versions/6'
files = os.listdir(dataset_path)
print('Nama File = ', files)
# Out:
# Nama File =  ['StudentPerformanceFactors.csv']

# %%
import pandas as pd
data_file = os.path.join(dataset_path, 'StudentPerformanceFactors.csv')
data = pd.read_csv(data_file)
data
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# # **cara download data csv 2**

# %%
data2 = pd.read_csv('StudentPerformanceFactors.csv')
data2
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
data2.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
data2.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %% [markdown]
# # **Linear Regression**

# %%
X = data[['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores']]  # Features
y = data['Exam_Score']  # Target

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

#split data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state = 0)

#training
model = LinearRegression()
model.fit(x_train, y_train)

#evaluasi
y_pred = model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
print(f'Hasil MSE = {mse:.3f}')
# Out:
# Hasil MSE = 7.465

# %%
model.coef_
# Out:
# array([ 0.29617342,  0.19828089, -0.03016091,  0.0460958 ])

# %% [markdown]
# Feature importance

# %%
import numpy as np
feature_importance = pd.DataFrame({
    'Feature': X.columns,   # Pastikan menggunakan X, yang sudah berisi fitur
    'Importance': model.coef_[0]
})


feature_importance = feature_importance.sort_values(by='Importance', ascending=False)
print(feature_importance)
# Out:
#            Feature  Importance
# 0    Hours_Studied    0.296173
# 1       Attendance    0.296173
# 2      Sleep_Hours    0.296173
# 3  Previous_Scores    0.296173

# %% [markdown]
# berdasarkan hasil feature importance dari model linear regression, dapat dilihat bahwa Hours_Studied ( jam belajar per minggu ) memiliki nilai kepentingan (importance) yang paling tinggi, sehingga menunjukan pengaruh paling besar terhadap Exam Score ( Nilai Ujian). Attendance (kehadiran) juga memberikan pengaruh terhadap Exam score, namun tidak lebih tinggi di bandingkan Hours_studied, begitu juga dengan previous_scores.
#
# sedangkan sleep hours dikarenakan memeberikan hasil berupa minus pada nilai importance, sehingga tidak memebrikan pengaruh pada prediksi model atau terhadap Exam score.
#
# correlation

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
import matplotlib.pyplot as plt
import seaborn  as sns

plt.figure(figsize = (5,4))
sns.heatmap(data[['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores','Tutoring_Sessions','Physical_Activity']].corr(), annot= True, fmt = '.2f')
# Out:
# <Axes: >

# %% [markdown]
# #**Khusus Tipe Sekolah : PUBLIK**

# %%
data_sekolah_publik = data2[data2['School_Type'] == 'Public']
data_sekolah_publik
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6601             20          83               Medium                 Low
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
data_sleep= data2[data2['Sleep_Hours'] > 6 ]
data_sleep
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 5                19          88               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6595             28          78               Medium                High
# 6596             17          92               Medium              Medium
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# #klasifikasi / Classification

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data2['Parental_Involvement_encoded'] = label_encoder.fit_transform(data2['Parental_Involvement'])
data2
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print(label_mapping)
# Out:
# {'High': 0, 'Low': 1, 'Medium': 2}

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

X = data2[['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores']]  # Features
y = data2['Parental_Involvement_encoded']  # Target

#split data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state = 0)

#training
model = LogisticRegression()
model.fit(x_train, y_train)

#evaluasi
y_pred = model.predict(x_test)

akurasi = accuracy_score(y_test, y_pred)
print(f'Hasil akurasi model = {akurasi:.2%}')
# Out:
# Hasil akurasi model = 50.98%
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
model.coef_[0]
# Out:
# array([ 2.83159697e-04,  8.35429898e-05,  9.34374165e-03, -2.16303518e-03])

# %%
import numpy as np
feature_importance = pd.DataFrame({
    'Feature': X.columns,   # Pastikan menggunakan X, yang sudah berisi fitur
    'Importance': model.coef_[0]
})


feature_importance = feature_importance.sort_values(by='Importance', ascending=False)
print(feature_importance)
# Out:
#            Feature  Importance
# 2      Sleep_Hours    0.009344
# 0    Hours_Studied    0.000283
# 1       Attendance    0.000084
# 3  Previous_Scores   -0.002163
